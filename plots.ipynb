# %%
plt.figure()
sns.lineplot(x=df['Date'], y=df['Depth_to_Groundwater_P24'].interpolate(), color='darkorange', label = 'modified')
sns.lineplot(x=df['Date'], y=df['Depth_to_Groundwater_P24'].fillna(np.inf), color='dodgerblue', label = 'original')
# plt.xlim (([date(2012, 1, 1), date(2020, 6, 30)]))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(x ='tip', y = 'total_bill', data =df, c= 'g', s= 50)
plt.scatter(x ='tip', y = 'size', data =df, c= 'r',marker ='+')
plt.legend(['total_bill', 'size'],title = 'plot')
plt.xlabel('tip',fontsize = 14)
plt.ylabel('bill and size')

sns.lmplot(x ='tip', y = 'total_bill', data =df, fit_reg=False )
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="499.84">

# %%
plt.figure()
df.tip.plot(kind = 'hist')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.distplot(df.tip, kde =False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
df.sex.value_counts().plot(kind = 'bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.countplot(df.sex)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure()
df.groupby(['time','day'])['tip'].agg(['mean','std']).plot(kind = 'barh', stacked = True)
plt.xticks(rotation = 10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (array([0., 1., 2., 3., 4., 5.]), <a list of 6 Text major ticklabel objects>)

# %%
plt.figure()
sns.boxplot(df.tip)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.lmplot(x='total_bill', y='tip', data=df, fit_reg=False, hue ='size' )
# Out:
# <img src="data:image/png;base64,..." width="872.96">

# %%
plt.subplot(121)
sns.distplot(df.tip)

plt.subplot(122)
sns.distplot(df.total_bill)
# Out:
# <ipython-input-15-b5f4b7fce640>:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(121)
# <ipython-input-15-b5f4b7fce640>:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(122)

# %%
fig, (ax1,ax2) =plt.subplots(1,2)
sns.distplot(df.tip, ax =ax2)
sns.distplot(df.total_bill, ax =ax1)
ax1.set_ylabel('total bill')
ax2.set_ylabel('fdg')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'fdg')

# %%
from datetime import date
df = pd.read_csv("D:\working directory\Kaggle datasets/acea-water-prediction/Aquifer_Petrignano.csv")
df['Date'] = pd.to_datetime(df['Date'], format = '%d/%m/%Y')
df
# Out:
#            Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0    2006-03-14                    NaN                    -22.48
# 1    2006-03-15                    NaN                    -22.38
# 2    2006-03-16                    NaN                    -22.25
# 3    2006-03-17                    NaN                    -22.38
# 4    2006-03-18                    NaN                    -22.60
# ...         ...                    ...                       ...
# 5218 2020-06-26                    0.0                    -25.68
# 5219 2020-06-27                    0.0                    -25.80
# 5220 2020-06-28                    0.0                    -25.80
# 5221 2020-06-29                    0.0                    -25.78
# 5222 2020-06-30                    0.0                    -25.91
#
#       Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# 0                       -22.18                       NaN
# 1                       -22.14                       NaN
# ...

# %%
# %matplotlib inline
f, ax = plt.subplots(nrows=7, ncols=1, figsize=(15,25))
for i, col in enumerate (df.drop('Date', axis = 1).columns):
#     print(1, col)
    sns.lineplot(x = df['Date'], y = df[col], ax = ax[i])
#     ax[i].set_xlim([date(2018,1,1), date(2020,2,1)])

# %%
# %matplotlib notebook
df[['Date','Depth_to_Groundwater_P24']].resample('y', on='Date').mean().plot()
plt.xlim (([date(2012, 1, 1), date(2020, 6, 30)]))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (42.0, 50.0)

# %%
# plt.rcParams['figure.dpi']=150
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import scipy.stats
# %matplotlib inline

x=df.tip
y=df.total_bill
slope, intercept, r, p, stderr = scipy.stats.linregress(x, y)

line = f'regression line,  p = {p:.3f}, r={r:.3f}'

fig, ax = plt.subplots(figsize = (10,6),dpi=150)
ax.plot(x, y,  linewidth=0,marker='o', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('tip amount')
ax.set_ylabel('total_bill')
ax.legend(facecolor='white')
ax.text(8,15,'xyzzzzz',fontsize = 12)
# Out:
# Text(8, 15, 'xyzzzzz')

# %%
p
# Out:
# 6.692470646864404e-34
